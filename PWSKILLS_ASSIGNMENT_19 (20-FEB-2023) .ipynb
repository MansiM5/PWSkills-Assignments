# %%
Q1. Explain GET and POST methods.

# %% [markdown]
# GET is a method that is used to pass the data in url whereas POST is a method in which data is passed through forms/body.

# %%
Q2. Why is request used in Flask?

# %% [markdown]
# Request is an object that contains all data sent from client to server.

# %%
Q3. Why is redirect() used in Flask?

# %% [markdown]
# redirect() redirects the user to some specified url with the status code.

# %%
Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# * A template is a file that contains a pre defined structure for rendering dynamic content.
# * render_template() is used to render a template with specified arguments.

# %%
Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)

@app.route("/postman_test1", methods= ['POST'])
def result1():
    if (request.method == 'POST'): #data sent through form
        marks1 = int(request.json['marks1'])
     
        if marks1 > 40 :
            result= "You are pass"
        else:
            result = "You are fail"
        
    return jsonify(result)

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# # ![Screenshot%201944-12-04%20at%209.33.51%20PM.png](attachment:Screenshot%201944-12-04%20at%209.33.51%20PM.png)
